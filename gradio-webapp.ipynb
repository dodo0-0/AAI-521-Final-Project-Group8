# %%
# !pip install gradio==3.50.2
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...
#    ---------------------------------------- 0.0/20.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/20.3 MB 1.7 MB/s eta 0:00:12
#     --------------------------------------- 0.5/20.3 MB 4.7 MB/s eta 0:00:05
#    -- ------------------------------------- 1.0/20.3 MB 8.3 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/20.3 MB 8.3 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/20.3 MB 8.3 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/20.3 MB 8.3 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/20.3 MB 8.3 MB/s eta 0:00:03
#    --- ------------------------------------ 1.9/20.3 MB 5.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.1/20.3 MB 5.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.1/20.3 MB 5.5 MB/s eta 0:00:04
# ...

# %%
import gradio as gr
print(gr.__version__)
# Out:
# 3.50.2

# %%
# %pip list
# Out:
# Package                      Version
# ---------------------------- ---------------
# absl-py                      2.3.1
# accelerate                   1.11.0
# aiofiles                     23.2.1
# aiohappyeyeballs             2.6.1
# aiohttp                      3.13.2
# aiosignal                    1.4.0
# albucore                     0.0.24
# albumentations               2.0.8
# altair                       5.5.0
# annotated-doc                0.0.4
# annotated-types              0.7.0
# antlr4-python3-runtime       4.9.3
# anyio                        4.9.0
# argon2-cffi                  25.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# async-lru                    2.0.5
# attrs                        25.4.0
# babel                        2.17.0
# beartype                     0.22.6
# beautifulsoup4               4.13.4
# bleach                       6.2.0
# ...

# %%
# RestorAI - FINAL FULLY WORKING VERSION (CPU + Inpainting + SwinIR)
# University of San Diego - AAI-521 Extra Credit - November 2025

import gradio as gr
import torch
from PIL import Image, ImageFilter
import numpy as np
import os
import io
import base64

from diffusers import UNet2DModel, DDPMScheduler, StableDiffusionInpaintPipeline
from diffusers.models.attention_processor import AttnProcessor
import numpy as np

# ==================== OPTIONAL: Your Trained Models ====================
print("Loading your custom models (if available)...")

# Denoising DDPM
denoise_model = UNet2DModel(
    sample_size=128, in_channels=3, out_channels=3,
    layers_per_block=2,
    block_out_channels=(128, 128, 256, 256, 512, 512),
    down_block_types=("DownBlock2D", "DownBlock2D", "DownBlock2D", "DownBlock2D", "AttnDownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "UpBlock2D", "UpBlock2D", "UpBlock2D", "UpBlock2D")
)
denoise_path = "RestorAI_Data/models/denoising_your_ddpm/pytorch_model.bin"
if os.path.exists(denoise_path):
    denoise_model.load_state_dict(torch.load(denoise_path, map_location="cpu"))
    print("Denoising model loaded.")
denoise_model.eval()
denoise_scheduler = DDPMScheduler(num_train_timesteps=1000)

# Super-Resolution SwinIR
have_swinir = False
sr_model = None

try:
    # 🚨 CRITICAL CHANGE: Use the exact import path from your working project
    # Ensure the 'SwinIR' folder (from the git clone) is in your project's PYTHONPATH
    from SwinIR.models.network_swinir import SwinIR 

    sr_path = "RestorAI_Data/models/super_res_your_swinir/swinir_x4.pth"
    
    if os.path.exists(sr_path):
        # 1. Define the Model Architecture (SwinIR-M Config) - This is now CORRECT
        sr_model = SwinIR(
            upscale=4,
            img_size=(64, 64),
            window_size=8,
            img_range=1.,
            embed_dim=180,
            depths=[6, 6, 6, 6, 6, 6],
            num_heads=[6, 6, 6, 6, 6, 6],
            mlp_ratio=2,
            upsampler='pixelshuffle',
            resi_connection='1conv'
        )
        
        # 2. Load the state dictionary
        checkpoint = torch.load(sr_path, map_location="cpu")
        
        # Extract the state_dict (handles models saved with a 'params' key)
        if 'params' in checkpoint:
            state_dict = checkpoint['params']
        else:
            state_dict = checkpoint
        
        # 3. Load strictly (This must work now because the class definitions match)
        sr_model.load_state_dict(state_dict, strict=True)
        sr_model.eval()
        have_swinir = True
        print("SwinIR-M model loaded successfully with matching architecture and keys!")

except Exception as e:
    have_swinir = False
    sr_model = None
    print("SwinIR failed to load, falling back to resize.")
    print("Final Load Error:", e)
    
# ==================== Stable Diffusion Inpainting ====================
print("Loading Stable Diffusion Inpainting model...")
inpaint_pipe = StableDiffusionInpaintPipeline.from_pretrained(
    "runwayml/stable-diffusion-inpainting",
    torch_dtype=torch.float32,
    safety_checker=None,
    requires_safety_checker=False,
    variant="fp16",
    use_safetensors=False
).to("cpu")

inpaint_pipe.unet.set_attn_processor(AttnProcessor())
inpaint_pipe.enable_attention_slicing()

print("Model ready – draw white on mask to delete objects!")

# ==================== Mask Handling ====================
def _prepare_mask_for_pipe(mask_input, target_size=(512, 512)):
    if mask_input is None:
        return None

    # --- 1. Extract Mask Image ---
    # Gradio Inpainting tools (ImageEditor, Image with tool='sketch') return a dict.
    # The mask data is often in the 'mask' or 'image' key, or sometimes 'composite' 
    # if using a component like ImageMask/ImageEditor. 
    # We will use the original input 'mask_input' when it's not a dict (like a PIL Image).
    
    if isinstance(mask_input, dict):
        # Prioritize 'composite' for ImageEditor, then 'mask' for older sketch/mask components
        # Fallback to 'image' if the mask is embedded there (uncommon, but safe)
        data = mask_input.get("composite") or mask_input.get("mask") or mask_input.get("image")
        
        if not data:
             # If the dictionary is present but no drawing was made, data might be empty
             return None 
        
        # Determine if 'data' is a PIL Image object, a Base64 string, or a NumPy array
        if isinstance(data, Image.Image):
            img = data # Already a PIL Image
        elif isinstance(data, str):
            # Handle the Base64 data string (e.g., "data:image/png;base64,...")
            if data.startswith("data:image"):
                data = data.split(",", 1)[1]
            try:
                img = Image.open(io.BytesIO(base64.b64decode(data)))
            except Exception as e:
                print(f"Error decoding base64 image data: {e}")
                return None
        elif isinstance(data, np.ndarray):
            # Handle NumPy array input (which Image.fromarray expects)
            img = Image.fromarray(data)
        else:
            # Fallback for unexpected data types within the dict
            return None
    else:
        # If the input is not a dictionary (e.g., a PIL Image object passed directly)
        img = mask_input

    # --- 2. Process Mask ---
    # Convert to single channel (Luminance)
    mask = img.convert("L").resize(target_size, Image.LANCZOS)
    
    # 1. CRITICAL INVERSION (Uncommented): 
    # This flips the drawn area (which is usually dark) to white (255), 
    # and the preserved background (light) to black (0).
    mask = Image.eval(mask, lambda p: 255 - p) 
    
    mask_np = np.array(mask)
    
    # 2. BINARIZATION (Corrected): 
    # Since the mask is already inverted (drawn area is white), we now 
    # strictly binarize it.
    # Pixels > 127 (white/drawn area) become 255 (INPAINT).
    # Pixels <= 127 (black/preserved background) become 0 (PRESERVE).
    # This removes the implicit inversion from your original np.where logic.
    mask_np = np.where(mask_np > 127, 255, 0).astype(np.uint8)
    
    # --- 3. Blur and Finalize ---
    # Apply Gaussian blur to soften the mask edges for better blending in the diffusion model
    mask = Image.fromarray(mask_np).filter(ImageFilter.GaussianBlur(radius=2))
    mask_np = np.array(mask)
    
    # Create the final 3-channel (RGB) mask needed by most Diffusers pipelines
    final_mask = Image.fromarray(np.stack([mask_np]*3, axis=-1))
    
    return final_mask

# ==================== Restoration Functions ====================
def denoise_image(img):
    if img is None: return None
    try:
        small = img.resize((128, 128))
        tensor = torch.from_numpy(np.array(small).astype(np.float32)/255.0).permute(2,0,1).unsqueeze(0)
        with torch.no_grad():
            noisy = denoise_scheduler.add_noise(tensor, torch.randn_like(tensor), torch.tensor([500]))
            pred = denoise_model(noisy, torch.tensor([500])).sample
            pred = torch.clamp(pred, 0, 1)
        result = Image.fromarray((pred[0].permute(1,2,0).numpy()*255).astype(np.uint8))
        return result.resize(img.size)
    except:
        return img

def super_resolve_image(img):
    if img is None: return None
    if sr_model is None or not have_swinir:
        return img.resize((img.width*2, img.height*2), Image.LANCZOS)
    try:
        small = img.resize((64,64), Image.LANCZOS)
        tensor = torch.from_numpy(np.array(small).astype(np.float32)/255.0).permute(2,0,1).unsqueeze(0)
        with torch.no_grad():
            sr = sr_model(tensor)
        result = Image.fromarray((sr[0].permute(1,2,0).numpy()*255).astype(np.uint8))
        return result.resize(img.size, Image.LANCZOS)
    except:
        return img.resize((img.width*2, img.height*2), Image.LANCZOS)

def colorize_image(img):
    return img.convert("L").convert("RGB")

def inpaint_image(image, mask_input):
    if image is None or mask_input is None:
        return image
    orig_size = image.size
    img_512 = image.convert("RGB").resize((512, 512), Image.LANCZOS)
    mask = _prepare_mask_for_pipe(mask_input, (512, 512))
    try:
        with torch.no_grad():
            result = inpaint_pipe(
                prompt="pavement, asphalt road, green bushes, blue sky, trees, outdoor photo", # Ensure you are using the updated, descriptive prompt
                negative_prompt="stop sign, pole, text, artifact, blurry, low quality",
                image=img_512,
                mask_image=mask,
                strength=0.95,
                num_inference_steps=50,
                guidance_scale=12.0,
                generator=None #torch.Generator("cpu").manual_seed(42),
            ).images[0]
        return result.resize(orig_size, Image.LANCZOS)
    except Exception as e:
        print("Inpaint error:", e)
        return image

# ==================== Gradio Interface ====================
with gr.Blocks(title="RestorAI", theme=gr.themes.Soft()) as demo:
    gr.Markdown("# RestorAI: AI Image Restoration System")
    gr.Markdown("### AAI-521 Extra Credit Project • University of San Diego")

    with gr.Row():
        with gr.Column():
            input_img = gr.Image(type="pil", label="Upload Image", height=450)
            mask_img = gr.Image(
                type="pil",
                label="Mask → Draw in WHITE the areas you want restored/removed",
                tool="sketch",
                brush_radius=40,
                brush_color="#FFFFFF",
                value=Image.new("RGB", (512, 512), (0,0,0)),
                height=512
            )
            task = gr.Dropdown(
                ["Inpaint", "Denoise", "Super-Resolution", "Colorize"],
                value="Inpaint",
                label="Select Task"
            )
            btn = gr.Button("Restore Image", variant="primary", size="lg")

        with gr.Column():
            output_img = gr.Image(type="pil", label="Restored Result", height=650)

    btn.click(
        fn=lambda img, mask, t: (
            inpaint_image(img, mask) if t=="Inpaint" else
            denoise_image(img) if t=="Denoise" else
            super_resolve_image(img) if t=="Super-Resolution" else
            colorize_image(img)
        ),
        inputs=[input_img, mask_img, task],
        outputs=output_img
    )

print("Launching RestorAI")
demo.launch(share=False, server_name="0.0.0.0", debug=True)
# Out:
# Loading your custom models (if available)...
# Denoising model loaded.
# SwinIR-M model loaded successfully with matching architecture and keys!
# Loading Stable Diffusion Inpainting model...
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Model ready – draw white on mask to delete objects!
# Launching RestorAI
# Running on local URL:  http://0.0.0.0:7860
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## 2. Integration and Deployment (Step 2 – Complete)
#
# **Public Web Application**:
# https://your-final-gradio-link.gradio.live
#
# Users can:
# - Upload any image
# - Select task (Super-Resolution / Denoise)
# - View real-time results from your trained models
#
# Built with Gradio (industry-standard for ML demos) using `demo.queue()` and `share=True` for reliable deployment.
